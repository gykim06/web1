# %% [markdown]
# <a href="https://colab.research.google.com/github/gykim06/web1/blob/master/%ED%8C%8C%EC%9D%B4%EC%8D%AC%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D%EA%B8%B0%EC%B4%88_5%EA%B0%95_%EC%8B%A4%EC%8A%B5(%EC%9B%90%EB%B3%B8).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 5강

# %% [markdown]
# ## 5장 1절

# %% [markdown]
# **비교 연산자**

# %%
# 3 > 6, suf == vol, light_on = 3 > 6, isStop = suf == vol

#print(3 < 6)

suf = 15
vol = 20
print(suf != vol)
isStop = suf != vol
print(isStop)
print(type(isStop))
# Out:
# True
# True
# <class 'bool'>

# %% [markdown]
# **원뿔의 부피&겉넓이 계산 프로그램 6**

# %%
# 원뿔 부피 및 겉넓이 계산 프로그램
# 반지름 과 높이 사용자 입력
rad = int(input("반지름을 입력하세요: "))
hei = int(input("높이를 입력하세요: "))

if rad >= 0 :
    # 모선 계산
    sla = pow(rad ** 2 + hei ** 2, 0.5)
    #부피 & 겉넓이 출력
    vol = 1 / 3 * 3.14 * rad ** 2 * hei
    suf = 3.14 * rad ** 2 + 3.14 * rad * sla
    print("원뿔의 부피는", str(vol) + "입니다.")
    print("원뿔의 겉넓이는", str(suf) + "입니다.")
# Out:
# 반지름을 입력하세요: -5
# 높이를 입력하세요: 20

# %%
# temp >= 27 and fruit == "apple"
# temp >= 27 or fruit == "apple"
# not temp >= 27

# %%
# 원뿔 부피 및 겉넓이 계산 프로그램
# 반지름 과 높이 사용자 입력
rad = int(input("반지름을 입력하세요: "))
hei = int(input("높이를 입력하세요: "))

if  not(rad < 0 or hei < 0) :
    # 모선 계산
    sla = pow(rad ** 2 + hei ** 2, 0.5)
    #부피 & 겉넓이 출력
    vol = 1 / 3 * 3.14 * rad ** 2 * hei
    suf = 3.14 * rad ** 2 + 3.14 * rad * sla
    print("원뿔의 부피는", str(vol) + "입니다.")
    print("원뿔의 겉넓이는", str(suf) + "입니다.")
else :
    print("반지름과 높이는 음수일 수 없습니다,")
# Out:
# 반지름을 입력하세요: 10
# 높이를 입력하세요: -25
# 반지름과 높이는 음수일 수 없습니다,

# %% [markdown]
# ## 5강 2절

# %% [markdown]
# **논리 연산자**

# %% [markdown]
# **원뿔의 부피&겉넓이 계산 프로그램 7**

# %%
print (not(3 < 6 or 6 < 10))
# Out:
# False

# %% [markdown]
# **가장 큰 수 찾는 프로그램**

# %%
a = int(input("첫 번째 수 입력 : "))
b = int(input("두 번째 수 입력 : "))
c = int(input("세 번째 수 입력 : "))

# 가장 큰 수 찾기
if a > b :
    if a > c :
        max = a
    else :
        max = c
else :
    if b > c :
        max = b
    else :
        max = c

print("가장 큰 수는 ",  str(max) + "입니다.")
# Out:
# 첫 번째 수 입력 : 10
# 두 번째 수 입력 : 20
# 세 번째 수 입력 : 30
# 가장 큰 수는  30입니다.

# %%
# 간결하게 큰 수 찾는 프로그램
a = int(input("첫 번째 수 입력 : "))
b = int(input("두 번째 수 입력 : "))
c = int(input("세 번째 수 입력 : "))

# 가장 큰 수 찾기
if b > a :
    a = b

if c > a :
    a = c

print("가장 큰 수는 ",  str(a) + "입니다.")

# 한 줄 한 줄 지나갈 수록 가장 큰 값이 a에만 남게끔 처리
# Out:
# 첫 번째 수 입력 : 10
# 두 번째 수 입력 : 50
# 세 번째 수 입력 : 30
# 가장 큰 수는  50입니다.
